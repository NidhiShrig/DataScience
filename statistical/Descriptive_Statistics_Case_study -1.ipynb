# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_excel("data/CardioGoodFitness.xlsx")

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    str
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    str
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    str
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), str(3)
# memory usage: 12.8 KB

# %%
data.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    34.988889   16.516667    3.394444    2.866667   53503.788889
# std      9.415896    2.874420    1.611749    1.395924   23173.230221
# min     18.000000   12.000000    1.000000    1.000000   25161.000000
# 25%     28.000000   14.000000    2.000000    2.000000   37216.000000
# 50%     35.000000   17.000000    3.000000    3.000000   45643.000000
# 75%     43.000000   19.000000    5.000000    4.000000   63114.500000
# max     50.000000   21.000000    6.000000    5.000000  116197.000000
#
#             Miles
# count  180.000000
# mean   101.505556
# std     42.246086
# min     40.000000
# 25%     70.000000
# 50%     98.000000
# 75%    125.000000
# max    219.000000

# %% [markdown]
# Age:
# Mean:34
# Range: 18-50
# Majority of customer are older
#
# Income:
# Mean:53719
# Range:29562-116197
# Customer belong to middle income group
#
# Usage:
# Mean 3.4 times/week
# Customers typically exercise 3-4 days per week
#
# Miles:
# Mean 101 miles/week
# some customers run very high disance who are serious runers

# %%
data.nunique()
# Out:
# Product            3
# Age               33
# Gender             2
# Education         10
# MaritalStatus      2
# Usage              6
# Fitness            5
# Income           179
# Miles            103
# dtype: int64

# %%
data['Product'].value_counts()
# Out:
# Product
# TM195    95
# TM498    50
# TM798    35
# Name: count, dtype: int64

# %% [markdown]
# TM195 is niche product

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      91
# Female    89
# Name: count, dtype: int64

# %% [markdown]
# Male customers dominate the dataset

# %%
data.groupby('Product')['Income'].mean()
# Out:
# Product
# TM195    37465.926316
# TM498    55491.020000
# TM798    94196.228571
# Name: Income, dtype: float64

# %% [markdown]
# TM798 is a premium product
# Income strongly influence product selection

# %%
data.groupby('Product')['Usage'].mean()
# Out:
# Product
# TM195    3.284211
# TM498    3.700000
# TM798    3.257143
# Name: Usage, dtype: float64

# %% [markdown]
# All threadmill usage is same

# %%
data.groupby('Product')['Fitness'].mean()
# Out:
# Product
# TM195    2.989474
# TM498    2.840000
# TM798    2.571429
# Name: Fitness, dtype: float64

# %% [markdown]
# customes are distributed equally in all products

# %%
data.corr(numeric_only=True)
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000  -0.028065  0.043728 -0.091921 -0.007977  0.035687
# Education -0.028065   1.000000 -0.022530 -0.070451  0.074633  0.086490
# Usage      0.043728  -0.022530  1.000000 -0.060918  0.062772 -0.021980
# Fitness   -0.091921  -0.070451 -0.060918  1.000000 -0.135356 -0.139339
# Income    -0.007977   0.074633  0.062772 -0.135356  1.000000  0.709345
# Miles      0.035687   0.086490 -0.021980 -0.139339  0.709345  1.000000

# %% [markdown]
# People with higher income run more

# %%
sns.countplot(x='Product', data=data)
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %% [markdown]
# TM195 has highest sales
# TM798  has lowest sales but serves higher value market

# %%
sns.boxplot(x='Product', y='Income', data=data)
# Out:
# <Axes: xlabel='Product', ylabel='Income'>

# %%
sns.boxplot(x='Gender', y='Miles', data=data)
# Out:
# <Axes: xlabel='Gender', ylabel='Miles'>

# %%
sns.histplot(data['Age'], bins=10)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>
