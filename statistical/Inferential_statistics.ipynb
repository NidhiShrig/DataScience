# %% [markdown]
# Inferential statistics
# - parameter -> numerical measure that describe the population
# example: Average income of all employees in a company
# μ -> Average
# σ -> standard deviation
#
#
# statistic- Numerical value calculated from a sample
# eg: Average income of 100 selected customer
# x̄ ->mean
# SD -> standard deviation
#
# sampling - The process of selecting subset from population

# %% [markdown]
# Hypothesis -> Is a testable assumption or statement about a population parameter based on sample data
#
# 1. Null hypothesis(Ho)
